# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Read in the data
df = pd.read_csv('./processed/disasters_country_month.csv')

# %%
df
# Out:
#           Country  Start Month  Animal accident  Drought  Earthquake  \
# 0     Afghanistan          1.0                0        3           2
# 1     Afghanistan          2.0                0        0           5
# 2     Afghanistan          3.0                0        0           3
# 3     Afghanistan          4.0                0        1           6
# 4     Afghanistan          5.0                0        1           4
# ...           ...          ...              ...      ...         ...
# 1954     Zimbabwe          5.0                0        1           0
# 1955     Zimbabwe          8.0                0        0           0
# 1956     Zimbabwe         10.0                0        1           0
# 1957     Zimbabwe         11.0                0        1           0
# 1958     Zimbabwe         12.0                0        0           0
#
#       Epidemic  Extreme temperature   Flood  Fog  Glacial lake outburst  \
# ...

# %%
# Bar plot of the number of disasters for Japan


sns.barplot(x='Start Month', y='mean_deaths_per_month', data=df[df['Country'] == 'Japan'])
# Out:
# <Axes: xlabel='Start Month', ylabel='mean_deaths_per_month'>

# %%
# barplot of the number of disasters in japan
disasters =
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # barplot of the types of disasters in japan
# ----> 2 sns.barplot(x='Start Month', y='mean_deaths_per_month', hue='Disaster Type', data=df[df['Country'] == 'Japan'])
#
# File ~/git/WonderWise/.venv/lib64/python3.11/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
# ...
